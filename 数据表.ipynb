# %%
import pandas as pd  
import pyreadstat  
  
# 读取SPSS文件  
df, meta = pyreadstat.read_sav('demo.sav')  
  
# 打印数据框内容  
print(df)
# Out:
#       序号  @1、您的性别：  @2、您的年龄：  @3、您的婚姻状况：  @4、您的受教育程度是：  @5、您的政治面貌：  @7、您的信仰是：  \
# 0   94.0       1.0      58.0        -2.0           1.0         1.0        2.0
# 1   30.0       1.0      45.0         2.0           1.0         1.0        2.0
# 2   31.0       1.0      48.0         2.0           1.0         1.0        2.0
# 3   93.0       1.0      74.0         2.0           2.0         2.0        2.0
# 4   76.0       1.0      31.0         2.0           2.0         1.0        2.0
# ..   ...       ...       ...         ...           ...         ...        ...
# 89  43.0       1.0      36.0         2.0           2.0         2.0        1.0
# 90  50.0       1.0      59.0         2.0           3.0         1.0        2.0
# 91  53.0       1.0      49.0         2.0           2.0         2.0        1.0
# 92  55.0       1.0      19.0         2.0           2.0         1.0        2.0
# 93  58.0       1.0      50.0         2.0           5.0         1.0        2.0
#
# ...
